# %%
from __future__ import print_function
import tensorflow as tf
tf.compat.v1.disable_eager_execution()


import time
from PIL import Image
import numpy as np

from keras import backend
from keras.models import Model
from keras.applications.vgg16 import VGG16

from scipy.optimize import fmin_l_bfgs_b
from PIL import Image


#setting height and width of the image
height = 256
width = 256

#Enter the path of content image i.e. image you would like the characteristics to be transferred to.
content_image_path = '/content/drive/MyDrive/golden.jpg'
content_image = Image.open(content_image_path)
content_image = content_image.resize((width, height))
content_image

#Enter the path of style image i.e. image you would like to use as your style.
style_image_path = '/content/drive/MyDrive/purple.jpg'
style_image = Image.open(style_image_path)
style_image = style_image.resize((width, height))
style_image

#Convert images to 4_D array
content_array = np.asarray(content_image, dtype= 'float32')
content_array = np.expand_dims(content_array, axis=0)
print(content_array.shape)

style_array = np.asarray(style_image, dtype= 'float32')
style_array = np.expand_dims(style_array, axis=0)
print(style_array.shape)

#1) Subtract the mean RGB value from each channel in the input
#2) Flip the multidimensional array from RGB to BGR

content_array[:, :, :, 0] -= 103.939
content_array[:, :, :, 1] -= 116.779
content_array[:, :, :, 2] -= 123.68
content_array = content_array[:, :, :, ::-1]

style_array[:, :, :, 0] -= 103.939
style_array[:, :, :, 1] -= 116.779
style_array[:, :, :, 2] -= 123.68
style_array = style_array[:, :, :, ::-1]

#Defining variables in keras backend-->tensorflow
content_image = backend.variable(content_array)
style_image = backend.variable(style_array)
combination_image = backend.placeholder((1, height, width, 3))

#Concatenate all image data into a single tensor
input_tensor = backend.concatenate([content_image, style_image, combination_image], axis = 0)

#model object without the top layers/fully connected layers
model = VGG16(input_tensor=input_tensor, weights='imagenet', include_top = False)

layers = dict([(layer.name, layer.output) for layer in model.layers])

#Defining alpha and beta hyperparameters
content_weight = 0.025
style_weight = 5.0
total_variation_weight = 1.0

loss = backend.variable(0.)

#The content loss
def content_loss(content, combination):
    return backend.sum(backend.square(combination - content))

layer_features = layers['block2_conv2']
content_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]

loss = loss + content_weight * content_loss(content_image_features, combination_features)

#The style loss
def gram_matrix(x):
    features = backend.batch_flatten(backend.permute_dimensions(x, (2, 0, 1)))
    gram = backend.dot(features, backend.transpose(features))
    return gram

def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = height * width
    return backend.sum(backend.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

#VGG16 layers used
feature_layers = ['block1_conv2', 'block2_conv2',
                  'block3_conv3', 'block4_conv3',
                  'block5_conv3']

for layer_name in feature_layers:
    layer_features = layers[layer_name]
    style_features = layer_features[1, : ,: ,:]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_features, combination_features)
    loss += (style_weight / len(feature_layers)) * sl

def total_variation_loss(x):
    a = backend.square(x[:, :height-1, :width-1, :] - x[:, 1:, :width-1, :])
    b = backend.square(x[:, :height-1, :width-1, :] - x[:, :height-1, 1:, :])
    return backend.sum(backend.pow(a + b, 1.25))

loss += total_variation_weight * total_variation_loss(combination_image)

grads = backend.gradients(loss, combination_image)

outputs = [loss]
outputs += grads
f_outputs = backend.function([combination_image], outputs)

def eval_loss_and_grads(x):
    x = x.reshape((1, height, width, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    grad_values = outs[1].flatten().astype('float64')
    return loss_value, grad_values

class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

x = np.random.uniform(0, 255, (1, height, width, 3)) - 128.

iterations = 200

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun = 20)
    print('Current loss value:', min_val)
    end_time = time.time()
    print('Iteration %d completed in %ds' % (i, end_time - start_time))



x = x.reshape((height, width, 3))
x = x[:, :, ::-1]
x[:, :, 0] += 103.939
x[:, :, 1] += 116.779
x[:, :, 2] += 123.68
x = np.clip(x, 0, 255).astype('uint8')

Image.fromarray(x)

output_image = Image.fromarray(x)
output_image.save('sloth_sketch.jpg')

import matplotlib.pyplot as plt
plt.imshow(x)
# Out:
# (1, 256, 256, 3)
# (1, 256, 256, 3)
# Start of iteration 0
# Current loss value: 79038300000.0
# Iteration 0 completed in 3s
# Start of iteration 1
# Current loss value: 39160943000.0
# Iteration 1 completed in 1s
# Start of iteration 2
# Current loss value: 27225397000.0
# Iteration 2 completed in 2s
# Start of iteration 3
# Current loss value: 19570907000.0
# Iteration 3 completed in 2s
# Start of iteration 4
# Current loss value: 14930531000.0
# Iteration 4 completed in 2s
# Start of iteration 5
# Current loss value: 12352634000.0
# Iteration 5 completed in 1s
# Start of iteration 6
# Current loss value: 10506294000.0
# Iteration 6 completed in 2s
# Start of iteration 7
# Current loss value: 9459421000.0
# Iteration 7 completed in 2s
# Start of iteration 8
# Current loss value: 8744539000.0
# Iteration 8 completed in 2s
# Start of iteration 9
# Current loss value: 8187855400.0
# Iteration 9 completed in 2s
# Start of iteration 10
# Current loss value: 7853251000.0
# Iteration 10 completed in 2s
# Start of iteration 11
# Current loss value: 7570666500.0
# Iteration 11 completed in 2s
# Start of iteration 12
# Current loss value: 7352315000.0
# Iteration 12 completed in 2s
# Start of iteration 13
# Current loss value: 7196785000.0
# Iteration 13 completed in 2s
# Start of iteration 14
# Current loss value: 7049291000.0
# Iteration 14 completed in 2s
# Start of iteration 15
# Current loss value: 6919341000.0
# Iteration 15 completed in 2s
# Start of iteration 16
# Current loss value: 6808699000.0
# Iteration 16 completed in 2s
# Start of iteration 17
# Current loss value: 6717465600.0
# Iteration 17 completed in 2s
# Start of iteration 18
# Current loss value: 6641231000.0
# Iteration 18 completed in 2s
# Start of iteration 19
# Current loss value: 6567933400.0
# Iteration 19 completed in 1s
# Start of iteration 20
# Current loss value: 6507341000.0
# Iteration 20 completed in 2s
# Start of iteration 21
# Current loss value: 6454684700.0
# Iteration 21 completed in 2s
# Start of iteration 22
# Current loss value: 6410408000.0
# Iteration 22 completed in 1s
# Start of iteration 23
# Current loss value: 6366393000.0
# Iteration 23 completed in 2s
# Start of iteration 24
# Current loss value: 6325116000.0
# Iteration 24 completed in 2s
# Start of iteration 25
# Current loss value: 6289822000.0
# Iteration 25 completed in 2s
# Start of iteration 26
# Current loss value: 6255755300.0
# Iteration 26 completed in 2s
# Start of iteration 27
# Current loss value: 6222296000.0
# Iteration 27 completed in 2s
# Start of iteration 28
# Current loss value: 6191189000.0
# Iteration 28 completed in 2s
# Start of iteration 29
# Current loss value: 6162892300.0
# Iteration 29 completed in 2s
# Start of iteration 30
# Current loss value: 6138562000.0
# Iteration 30 completed in 2s
# Start of iteration 31
# Current loss value: 6114696000.0
# Iteration 31 completed in 2s
# Start of iteration 32
# Current loss value: 6090780700.0
# Iteration 32 completed in 2s
# Start of iteration 33
# Current loss value: 6071586300.0
# Iteration 33 completed in 2s
# Start of iteration 34
# Current loss value: 6053817300.0
# Iteration 34 completed in 2s
# Start of iteration 35
# Current loss value: 6036262400.0
# Iteration 35 completed in 2s
# Start of iteration 36
# Current loss value: 6019962000.0
# Iteration 36 completed in 2s
# Start of iteration 37
# Current loss value: 6005061600.0
# Iteration 37 completed in 2s
# Start of iteration 38
# Current loss value: 5990456000.0
# Iteration 38 completed in 2s
# Start of iteration 39
# Current loss value: 5976165400.0
# Iteration 39 completed in 2s
# Start of iteration 40
# Current loss value: 5964053500.0
# Iteration 40 completed in 2s
# Start of iteration 41
# Current loss value: 5952814000.0
# Iteration 41 completed in 2s
# Start of iteration 42
# Current loss value: 5942733000.0
# Iteration 42 completed in 2s
# Start of iteration 43
# Current loss value: 5932632600.0
# Iteration 43 completed in 2s
# Start of iteration 44
# Current loss value: 5923473400.0
# Iteration 44 completed in 2s
# Start of iteration 45
# Current loss value: 5913978000.0
# Iteration 45 completed in 2s
# Start of iteration 46
# Current loss value: 5904146400.0
# Iteration 46 completed in 2s
# Start of iteration 47
# Current loss value: 5895498000.0
# Iteration 47 completed in 2s
# Start of iteration 48
# Current loss value: 5887280000.0
# Iteration 48 completed in 2s
# Start of iteration 49
# Current loss value: 5879609000.0
# Iteration 49 completed in 2s
# Start of iteration 50
# Current loss value: 5871463400.0
# Iteration 50 completed in 2s
# Start of iteration 51
# Current loss value: 5863868000.0
# Iteration 51 completed in 2s
# Start of iteration 52
# Current loss value: 5856187400.0
# Iteration 52 completed in 2s
# Start of iteration 53
# Current loss value: 5848877600.0
# Iteration 53 completed in 2s
# Start of iteration 54
# Current loss value: 5841497000.0
# Iteration 54 completed in 2s
# Start of iteration 55
# Current loss value: 5833880000.0
# Iteration 55 completed in 2s
# Start of iteration 56
# Current loss value: 5827207000.0
# Iteration 56 completed in 2s
# Start of iteration 57
# Current loss value: 5819994000.0
# Iteration 57 completed in 2s
# Start of iteration 58
# Current loss value: 5812536300.0
# Iteration 58 completed in 2s
# Start of iteration 59
# Current loss value: 5804960000.0
# Iteration 59 completed in 2s
# Start of iteration 60
# Current loss value: 5797831000.0
# Iteration 60 completed in 2s
# Start of iteration 61
# Current loss value: 5790816000.0
# Iteration 61 completed in 2s
# Start of iteration 62
# Current loss value: 5783440000.0
# Iteration 62 completed in 2s
# Start of iteration 63
# Current loss value: 5776026600.0
# Iteration 63 completed in 2s
# Start of iteration 64
# Current loss value: 5768429000.0
# Iteration 64 completed in 2s
# Start of iteration 65
# Current loss value: 5760490000.0
# Iteration 65 completed in 2s
# Start of iteration 66
# Current loss value: 5753020000.0
# Iteration 66 completed in 2s
# Start of iteration 67
# Current loss value: 5745573400.0
# Iteration 67 completed in 2s
# Start of iteration 68
# Current loss value: 5738484000.0
# Iteration 68 completed in 2s
# Start of iteration 69
# Current loss value: 5731222000.0
# Iteration 69 completed in 2s
# Start of iteration 70
# Current loss value: 5723932700.0
# Iteration 70 completed in 2s
# Start of iteration 71
# Current loss value: 5716337700.0
# Iteration 71 completed in 2s
# Start of iteration 72
# Current loss value: 5708370000.0
# Iteration 72 completed in 2s
# Start of iteration 73
# Current loss value: 5701314600.0
# Iteration 73 completed in 2s
# Start of iteration 74
# Current loss value: 5694164500.0
# Iteration 74 completed in 2s
# Start of iteration 75
# Current loss value: 5686945300.0
# Iteration 75 completed in 2s
# Start of iteration 76
# Current loss value: 5679669000.0
# Iteration 76 completed in 2s
# Start of iteration 77
# Current loss value: 5672483300.0
# Iteration 77 completed in 2s
# Start of iteration 78
# Current loss value: 5665466400.0
# Iteration 78 completed in 2s
# Start of iteration 79
# Current loss value: 5658610700.0
# Iteration 79 completed in 2s
# Start of iteration 80
# Current loss value: 5651619300.0
# Iteration 80 completed in 2s
# Start of iteration 81
# Current loss value: 5644381000.0
# Iteration 81 completed in 2s
# Start of iteration 82
# Current loss value: 5637448000.0
# Iteration 82 completed in 2s
# Start of iteration 83
# Current loss value: 5630792000.0
# Iteration 83 completed in 2s
# Start of iteration 84
# Current loss value: 5623654400.0
# Iteration 84 completed in 2s
# Start of iteration 85
# Current loss value: 5617292000.0
# Iteration 85 completed in 2s
# Start of iteration 86
# Current loss value: 5611090400.0
# Iteration 86 completed in 2s
# Start of iteration 87
# Current loss value: 5604636700.0
# Iteration 87 completed in 2s
# Start of iteration 88
# Current loss value: 5597826000.0
# Iteration 88 completed in 2s
# Start of iteration 89
# Current loss value: 5591576000.0
# Iteration 89 completed in 2s
# Start of iteration 90
# Current loss value: 5585595000.0
# Iteration 90 completed in 2s
# Start of iteration 91
# Current loss value: 5579384300.0
# Iteration 91 completed in 2s
# Start of iteration 92
# Current loss value: 5573077000.0
# Iteration 92 completed in 2s
# Start of iteration 93
# Current loss value: 5566847000.0
# Iteration 93 completed in 2s
# Start of iteration 94
# Current loss value: 5560884000.0
# Iteration 94 completed in 2s
# Start of iteration 95
# Current loss value: 5554820600.0
# Iteration 95 completed in 2s
# Start of iteration 96
# Current loss value: 5549384000.0
# Iteration 96 completed in 2s
# Start of iteration 97
# Current loss value: 5544300500.0
# Iteration 97 completed in 2s
# Start of iteration 98
# Current loss value: 5539045400.0
# Iteration 98 completed in 2s
# Start of iteration 99
# Current loss value: 5534030300.0
# Iteration 99 completed in 2s
# Start of iteration 100
# Current loss value: 5529347000.0
# Iteration 100 completed in 2s
# Start of iteration 101
# Current loss value: 5524718600.0
# Iteration 101 completed in 2s
# Start of iteration 102
# Current loss value: 5520095700.0
# Iteration 102 completed in 2s
# Start of iteration 103
# Current loss value: 5515415000.0
# Iteration 103 completed in 2s
# Start of iteration 104
# Current loss value: 5510868500.0
# Iteration 104 completed in 1s
# Start of iteration 105
# Current loss value: 5506584600.0
# Iteration 105 completed in 2s
# Start of iteration 106
# Current loss value: 5502652000.0
# Iteration 106 completed in 2s
# Start of iteration 107
# Current loss value: 5498897400.0
# Iteration 107 completed in 2s
# Start of iteration 108
# Current loss value: 5495283700.0
# Iteration 108 completed in 2s
# Start of iteration 109
# Current loss value: 5491650600.0
# Iteration 109 completed in 2s
# Start of iteration 110
# Current loss value: 5487929000.0
# Iteration 110 completed in 2s
# Start of iteration 111
# Current loss value: 5484010000.0
# Iteration 111 completed in 2s
# Start of iteration 112
# Current loss value: 5479968300.0
# Iteration 112 completed in 2s
# Start of iteration 113
# Current loss value: 5475838000.0
# Iteration 113 completed in 2s
# Start of iteration 114
# Current loss value: 5471943700.0
# Iteration 114 completed in 2s
# Start of iteration 115
# Current loss value: 5467945000.0
# Iteration 115 completed in 2s
# Start of iteration 116
# Current loss value: 5463678500.0
# Iteration 116 completed in 2s
# Start of iteration 117
# Current loss value: 5459700700.0
# Iteration 117 completed in 2s
# Start of iteration 118
# Current loss value: 5456278000.0
# Iteration 118 completed in 2s
# Start of iteration 119
# Current loss value: 5453158000.0
# Iteration 119 completed in 2s
# Start of iteration 120
# Current loss value: 5450175500.0
# Iteration 120 completed in 2s
# Start of iteration 121
# Current loss value: 5447326700.0
# Iteration 121 completed in 2s
# Start of iteration 122
# Current loss value: 5444506600.0
# Iteration 122 completed in 2s
# Start of iteration 123
# Current loss value: 5441723400.0
# Iteration 123 completed in 2s
# Start of iteration 124
# Current loss value: 5439059000.0
# Iteration 124 completed in 2s
# Start of iteration 125
# Current loss value: 5436524500.0
# Iteration 125 completed in 2s
# Start of iteration 126
# Current loss value: 5434134000.0
# Iteration 126 completed in 2s
# Start of iteration 127
# Current loss value: 5431941600.0
# Iteration 127 completed in 2s
# Start of iteration 128
# Current loss value: 5429739500.0
# Iteration 128 completed in 2s
# Start of iteration 129
# Current loss value: 5427674600.0
# Iteration 129 completed in 2s
# Start of iteration 130
# Current loss value: 5425639000.0
# Iteration 130 completed in 2s
# Start of iteration 131
# Current loss value: 5423580700.0
# Iteration 131 completed in 2s
# Start of iteration 132
# Current loss value: 5421633000.0
# Iteration 132 completed in 2s
# Start of iteration 133
# Current loss value: 5419787300.0
# Iteration 133 completed in 2s
# Start of iteration 134
# Current loss value: 5417804000.0
# Iteration 134 completed in 2s
# Start of iteration 135
# Current loss value: 5415789600.0
# Iteration 135 completed in 2s
# Start of iteration 136
# Current loss value: 5413922000.0
# Iteration 136 completed in 2s
# Start of iteration 137
# Current loss value: 5412055600.0
# Iteration 137 completed in 2s
# Start of iteration 138
# Current loss value: 5410261000.0
# Iteration 138 completed in 2s
# Start of iteration 139
# Current loss value: 5408435700.0
# Iteration 139 completed in 2s
# Start of iteration 140
# Current loss value: 5406518300.0
# Iteration 140 completed in 2s
# Start of iteration 141
# Current loss value: 5404419600.0
# Iteration 141 completed in 2s
# Start of iteration 142
# Current loss value: 5402246700.0
# Iteration 142 completed in 2s
# Start of iteration 143
# Current loss value: 5400208400.0
# Iteration 143 completed in 2s
# Start of iteration 144
# Current loss value: 5398182000.0
# Iteration 144 completed in 2s
# Start of iteration 145
# Current loss value: 5396130000.0
# Iteration 145 completed in 2s
# Start of iteration 146
# Current loss value: 5394059300.0
# Iteration 146 completed in 2s
# Start of iteration 147
# Current loss value: 5392020000.0
# Iteration 147 completed in 2s
# Start of iteration 148
# Current loss value: 5390025700.0
# Iteration 148 completed in 2s
# Start of iteration 149
# Current loss value: 5388220400.0
# Iteration 149 completed in 2s
# Start of iteration 150
# Current loss value: 5386558500.0
# Iteration 150 completed in 2s
# Start of iteration 151
# Current loss value: 5384993300.0
# Iteration 151 completed in 2s
# Start of iteration 152
# Current loss value: 5383436300.0
# Iteration 152 completed in 2s
# Start of iteration 153
# Current loss value: 5381818000.0
# Iteration 153 completed in 2s
# Start of iteration 154
# Current loss value: 5380162600.0
# Iteration 154 completed in 2s
# Start of iteration 155
# Current loss value: 5378496500.0
# Iteration 155 completed in 2s
# Start of iteration 156
# Current loss value: 5376801300.0
# Iteration 156 completed in 2s
# Start of iteration 157
# Current loss value: 5375155000.0
# Iteration 157 completed in 2s
# Start of iteration 158
# Current loss value: 5373637600.0
# Iteration 158 completed in 2s
# Start of iteration 159
# Current loss value: 5372154400.0
# Iteration 159 completed in 2s
# Start of iteration 160
# Current loss value: 5370736000.0
# Iteration 160 completed in 2s
# Start of iteration 161
# Current loss value: 5369340000.0
# Iteration 161 completed in 3s
# Start of iteration 162
# Current loss value: 5368023000.0
# Iteration 162 completed in 2s
# Start of iteration 163
# Current loss value: 5366753300.0
# Iteration 163 completed in 2s
# Start of iteration 164
# Current loss value: 5365609500.0
# Iteration 164 completed in 2s
# Start of iteration 165
# Current loss value: 5364519000.0
# Iteration 165 completed in 2s
# Start of iteration 166
# Current loss value: 5363483600.0
# Iteration 166 completed in 2s
# Start of iteration 167
# Current loss value: 5362415600.0
# Iteration 167 completed in 2s
# Start of iteration 168
# Current loss value: 5361324000.0
# Iteration 168 completed in 2s
# Start of iteration 169
# Current loss value: 5360220700.0
# Iteration 169 completed in 2s
# Start of iteration 170
# Current loss value: 5359105500.0
# Iteration 170 completed in 2s
# Start of iteration 171
# Current loss value: 5358068700.0
# Iteration 171 completed in 2s
# Start of iteration 172
# Current loss value: 5357042000.0
# Iteration 172 completed in 2s
# Start of iteration 173
# Current loss value: 5356091000.0
# Iteration 173 completed in 2s
# Start of iteration 174
# Current loss value: 5355152000.0
# Iteration 174 completed in 2s
# Start of iteration 175
# Current loss value: 5354221600.0
# Iteration 175 completed in 2s
# Start of iteration 176
# Current loss value: 5353273000.0
# Iteration 176 completed in 2s
# Start of iteration 177
# Current loss value: 5352270000.0
# Iteration 177 completed in 2s
# Start of iteration 178
# Current loss value: 5351320600.0
# Iteration 178 completed in 2s
# Start of iteration 179
# Current loss value: 5350396400.0
# Iteration 179 completed in 2s
# Start of iteration 180
# Current loss value: 5349528000.0
# Iteration 180 completed in 2s
# Start of iteration 181
# Current loss value: 5348640000.0
# Iteration 181 completed in 2s
# Start of iteration 182
# Current loss value: 5347728400.0
# Iteration 182 completed in 2s
# Start of iteration 183
# Current loss value: 5346801000.0
# Iteration 183 completed in 2s
# Start of iteration 184
# Current loss value: 5345886000.0
# Iteration 184 completed in 2s
# Start of iteration 185
# Current loss value: 5345061000.0
# Iteration 185 completed in 2s
# Start of iteration 186
# Current loss value: 5344239600.0
# Iteration 186 completed in 2s
# Start of iteration 187
# Current loss value: 5343447000.0
# Iteration 187 completed in 2s
# Start of iteration 188
# Current loss value: 5342685000.0
# Iteration 188 completed in 2s
# Start of iteration 189
# Current loss value: 5341899000.0
# Iteration 189 completed in 2s
# Start of iteration 190
# Current loss value: 5341140500.0
# Iteration 190 completed in 2s
# Start of iteration 191
# Current loss value: 5340376600.0
# Iteration 191 completed in 2s
# Start of iteration 192
# Current loss value: 5339638000.0
# Iteration 192 completed in 2s
# Start of iteration 193
# Current loss value: 5338894300.0
# Iteration 193 completed in 1s
# Start of iteration 194
# Current loss value: 5338162700.0
# Iteration 194 completed in 2s
# Start of iteration 195
# Current loss value: 5337413600.0
# Iteration 195 completed in 2s
# Start of iteration 196
# Current loss value: 5336712000.0
# Iteration 196 completed in 2s
# Start of iteration 197
# Current loss value: 5336054000.0
# Iteration 197 completed in 2s
# Start of iteration 198
# Current loss value: 5335450000.0
# Iteration 198 completed in 2s
# Start of iteration 199
# Current loss value: 5334895000.0
# Iteration 199 completed in 2s
